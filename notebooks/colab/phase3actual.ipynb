# %%
# !git clone https://github.com/sahilahmed21/Atlas.git
# Out:
# fatal: destination path 'Atlas' already exists and is not an empty directory.

# %%
# %cd Atlas
# Out:
# /content/Atlas

# %%
# !find . -maxdepth 3
# Out:
# .
# ./.python-version
# ./benchmarks
# ./benchmarks/routing
# ./benchmarks/routing/.gitkeep
# ./benchmarks/compare
# ./benchmarks/compare/.gitkeep
# ./benchmarks/load
# ./benchmarks/load/.gitkeep
# ./benchmarks/README.md
# ./uv.lock
# ./.git
# ./.git/hooks
# ./.git/hooks/fsmonitor-watchman.sample
# ./.git/hooks/post-update.sample
# ./.git/hooks/push-to-checkout.sample
# ./.git/hooks/pre-rebase.sample
# ./.git/hooks/pre-applypatch.sample
# ./.git/hooks/commit-msg.sample
# ./.git/hooks/pre-merge-commit.sample
# ./.git/hooks/pre-commit.sample
# ./.git/hooks/pre-push.sample
# ./.git/hooks/pre-receive.sample
# ./.git/hooks/prepare-commit-msg.sample
# ./.git/hooks/applypatch-msg.sample
# ./.git/hooks/update.sample
# ./.git/index
# ./.git/description
# ./.git/packed-refs
# ./.git/info
# ./.git/info/exclude
# ./.git/config
# ./.git/logs
# ./.git/logs/HEAD
# ./.git/logs/refs
# ./.git/branches
# ./.git/HEAD
# ./.git/objects
# ./.git/objects/info
# ./.git/objects/pack
# ./.git/refs
# ...

# %%
# !pip install https://github.com/vllm-project/vllm/releases/download/v0.26.0/vllm-0.26.0+cu129-cp38-abi3-manylinux_2_28_x86_64.whl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.9/518.9 MB 3.3 MB/s eta 0:00:00
# ...

# %%
# !python scripts/verify_wsl_vllm.py
# Out:
# vllm 0.26.0 (pin ok) 0.26.0
# torch 2.11.0+cu128
# cuda True
# device Tesla T4

# %%
# !python fundamentals/experiments/vllm_load.py
# Out:
# vllm=0.26.0 model=Qwen/Qwen2.5-0.5B-Instruct rev=7ae557604adf dtype=float16
# INFO 08-06 20:52:17 [api_utils.py:273] non-default args: {'dtype': 'float16', 'disable_log_stats': True, 'revision': '7ae557604adf67be50417f59c2c2f167def9a775', 'model': 'Qwen/Qwen2.5-0.5B-Instruct'}
# ...
# config.json: 100% 659/659 [00:00<00:00, 3.06MB/s]
# INFO 08-06 20:52:33 [model.py:623] Resolved architecture: Qwen2ForCausalLM
# WARNING 08-06 20:52:33 [model.py:2123] Casting torch.bfloat16 to torch.float16.
# INFO 08-06 20:52:33 [model.py:1788] Using max model len 32768
# INFO 08-06 20:52:33 [scheduler.py:252] Chunked prefill is enabled with max_num_batched_tokens=8192.
# INFO 08-06 20:52:33 [vllm.py:1109] Asynchronous scheduling is enabled.
# INFO 08-06 20:52:33 [kernel.py:295] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native'])
# tokenizer_config.json: 100% 7.30k/7.30k [00:00<00:00, 4.83MB/s]
# ...

# %%
# !ls results/phase3
# Out:
# vllm_load.csv

# %%
# !cat results/phase3/vllm_load.csv
# Out:
# timestamp,hardware,model,n_concurrent,prompt_tokens,max_new_tokens,ttft_ms,total_ms,tokens_per_s,peak_vram_mb,status,notes
# 2026-08-06T20:54:06Z,colab-t4,Qwen/Qwen2.5-0.5B-Instruct,1,23,32,265.903,265.903,120.345,14956.2,ok,ttft_proxy=batch_wall; vram_source=nvml; batch_generate=1; vllm=0.26.0
# 2026-08-06T20:54:06Z,colab-t4,Qwen/Qwen2.5-0.5B-Instruct,2,23,32,210.426,210.426,152.073,14956.2,ok,ttft_proxy=batch_wall; vram_source=nvml; batch_generate=1; vllm=0.26.0
# 2026-08-06T20:54:06Z,colab-t4,Qwen/Qwen2.5-0.5B-Instruct,4,23,32,215.632,215.632,148.401,14956.2,ok,ttft_proxy=batch_wall; vram_source=nvml; batch_generate=1; vllm=0.26.0
# 2026-08-06T20:54:07Z,colab-t4,Qwen/Qwen2.5-0.5B-Instruct,8,23,32,228.654,228.654,139.949,14956.2,ok,ttft_proxy=batch_wall; vram_source=nvml; batch_generate=1; vllm=0.26.0

# %%
# !python fundamentals/experiments/plot_naive_vs_vllm.py
# Out:
# wrote /content/Atlas/results/phase3/naive_vs_vllm.png (4 points)
# ...

# %%
# !ls results/phase3
# Out:
# naive_vs_vllm.png  vllm_load.csv

# %%
from google.colab import files

files.download("results/phase3/vllm_load.csv")
files.download("results/phase3/naive_vs_vllm.png")
